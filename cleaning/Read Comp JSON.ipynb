# %%
import pandas as pd
import json
from toolz.curried import *

# %%
with open('../data/athlete_comps.json') as f:
    data = json.loads(f.read())
    athlete_comp_result = {athlete_id: merge(*[{comp['comp']: comp['result']} for comp in comps]) for athlete_id, comps in data.items()}
    df = pd.read_json(json.dumps(athlete_comp_result), orient='index')
df
# Out:
#        5378  5301  5300  5297  5246  5244  5243  9541  8181  8178  ...  1543  \
# 51001  21.0   8.0  13.0   9.0  12.0  11.0  15.0   NaN   NaN   NaN  ...   NaN
# 51004  25.0   NaN  16.0   NaN  18.0   NaN  20.0   NaN   NaN   NaN  ...   NaN
# 51012  17.0   4.0   5.0   6.0  13.0  12.0   7.0   NaN   NaN   NaN  ...   NaN
# 51027  14.0   6.0   NaN   NaN   NaN  11.0  18.0   NaN   NaN   NaN  ...   NaN
# 51213   7.0   NaN   3.0   5.0   NaN   NaN  12.0   NaN   NaN   NaN  ...   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 6897    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 6898    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 6900    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 6901    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 6903    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#        1542  1434  1515  1514  1559  6246  856   836   785
# 51001   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 51004   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 51012   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 51027   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 51213   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 6897    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.0
# 6898    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0
# 6900    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0
# 6901    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.0
# 6903    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   4.0
#
# [18879 rows x 1749 columns]
